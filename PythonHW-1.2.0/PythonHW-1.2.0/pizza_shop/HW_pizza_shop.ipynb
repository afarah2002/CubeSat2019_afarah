# %% [markdown]
# # Pizza Shop
# You work at a pizza restaurant, which is starting to accept orders online. You need to
# provide a python function that will accept an arbitrary order as its arguments,
# and compute the correct price for the order.
#
# Your cost-calculator function should have four arguments:
# - pizzas
# - drinks
# - wings
# - coupon
#
#
# A single pizza order is formed as a list of toppings. For example
# - A pizza with no toppings (other than cheese and sauce is: [] (an empty list)
# - A pizza with pepperoni and a double order of olives is : ["pepperoni", "olives", "olives"]
#
# *An arbitrary number of pizzas may be ordered, including no pizzas as all*
#
# Drinks come in as a named order (i.e. a keyword argument 'drinks'). If drinks are ordered,
# they are specified as a list of sizes (possible sizes: "small", "medium", "large", "tub"). For example, `drinks=["small", "small", "large"]` would indicate an order including two small drinks and a large drink.
#
# Wings come in as a named order as well (keyword argument 'wings'). If wings are ordered,
# they are specified as a list of integers (possible sizes: 10, 20, 40, 100). For example, `wings=[20]` would indicate a single order of 20-piece wings.
#
# A coupon may be specified as the keyword argument 'coupon'. It is will be a single
# floating point number between 0 and 1. This indicates the fraction of the *pre-tax*
# price that is to be subtracted. For example `coupon=.25` would indicate a 25%-off coupon.
#
# A 6.25% tax is applied to every order. The tax is computed on the total cost of the
# order *before a coupon is applied*
#
# Round the price to the nearest cent, using the built-in function round. `round(x, 2)` will round `x` to two decimal places.
#
# ## Prices
# The prices are as follows:
#
# **Pizza**
# - \$13.00
#
# **Toppings**
# - pepperoni : \$1.00
# - mushroom : \$0.50
# - olive : \$0.50
# - anchovy : \$2.00
# - ham : \$1.50
#
# **Drinks**
# - small : \$2.00
# - medium : \$3.00
# - large : \$3.50
# - tub : \$3.75
#
# **Wings**
# - 10 : \$5.00
# - 20 : \$9.00
# - 40 : \$17.50
# - 100 : \$48.00
#
#
# ## Examples
# The following is an order for a plain pizza, a ham and anchovy pizza, two "tub"-sized
# drinks, with a 10%-off coupon:
# ```python
# >>>cost_calculator([], ["ham", "anchovy"], drinks=["tub", "tub"], coupon=0.1)
# 35.61
# ```
#
# This order consists only of a small drink.
# ```python
# >>> cost_calculator(drinks=["small"])
# 2.12
# ```
#
# This is an order of two plain pizzas, a pizza with double-pepperoni, an order of a 10-piece and a 20-piece wings, and a small drink.
# ```python
# >>> cost_calculator([], [], ["pepperoni", "pepperoni"], wings=[10, 20], drinks=["small"])
# 60.56
# ```
#
# ## Details
# You can assume that the front-end of the website will never pass your function erroneous
# orders. That is, you will never receive orders for items that do not exist nor
# items that contain typos.
#
# Consider defining individual functions responsible for computing
# the cost of the pizzas, drinks, and wings, respectively. Have `cost_calculator`
# invoke these internally. Alternatively, you can read ahead about dictionaries and make nice
# use of these in this problem.
#
# Our `cost_calculator` signature is empty. Part of the assignment is to come up with the
# correct function signature!

# %%
# make sure to execute this cell so that your function is defined
# you must re-run this cell any time you make a change to this function
# write your code here
    # be sure to include a `return` statement so that
    # your function returns the appropriate object.

def cost_calculator(*top, **args):
       
     #drinks
    DKS = {"small":2.00, "medium":3.00, "large":3.50, "tub":3.75}
    WNG = {10:5.00, 20:9.00, 40:17.50, 100:48.00}
    TPG = {"pepperoni":1.00, "mushroom":0.50, "olive":0.50, "anchovy":2.00, "ham":1.50,} #if there is a pizza
        
    
    D = 0.00
    W = 0.00
    tpg_price = 0.00
    C = 0.00
    for a, b in args.items():
        if str(a) == "coupon":
            C = float(b)
        
        print(a,b)
        if type(b) == list:
            if str(a) == "drinks":
                for num in b:
                    D += DKS[num]
                print(D)
            if str(a) == "wings":
                for num in b: #mnultiple, different amounts of wings
                    W += WNG[num]
                print(W)
                
    for t in top:
        if not t == []:
            for pg in TPG.keys():
                for item in t:
                    if str(item) == pg:
                        tpg_price += TPG[pg] 
            tpg_price = tpg_price+13.00
                    
        else:
            tpg_price += 13.00
    
    
    TOTAL = D + W + tpg_price
    final = TOTAL + (TOTAL*0.0625) - (TOTAL*C)
    
    final = round(final, 2)
    return final

# %%
# Execute this cell to grade your work
from bwsi_grader.python.pizza_shop import grader
grader(cost_calculator)
# Out:
# drinks ['tub']
# 3.75
# coupon 0.1
# wings [10, 20]
# 14.0
# drinks ['tub', 'small']
# 5.75
# wings [10, 10]
# 10.0
# coupon 0.1
# drinks ['large', 'medium']
# 6.5
# wings [40, 10, 40]
# 40.0
# drinks ['large', 'tub']
# 7.25
# wings None
# drinks ['small', 'large', 'large']
# 9.0
# wings [20, 20, 100]
# 66.0
# drinks ['small']
# 2.0
# wings [40, 20]
# 26.5
# drinks ['large', 'large', 'tub']
# 10.75
# wings [20, 40, 40]
# 44.0
# drinks ['medium']
# 3.0
# wings [20]
# 9.0
# drinks ['large', 'medium']
# 6.5
# wings None
# drinks ['medium', 'medium', 'small']
# 8.0
# wings None
# drinks ['tub', 'large', 'small']
# 9.25
# wings None
# drinks ['large']
# 3.5
# wings [100]
# 48.0
# drinks ['small', 'tub']
# 5.75
# wings [20, 40]
# 26.5
# drinks ['medium', 'tub', 'medium']
# 9.75
# wings [100]
# 48.0
# drinks ['tub', 'large']
# 7.25
# wings [40]
# 17.5
# drinks ['small', 'tub']
# 5.75
# wings [10]
# 5.0
# drinks ['small', 'medium', 'large']
# 8.5
# wings [100, 10]
# 53.0
# drinks None
# wings [100, 40]
# 65.5
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks ['small', 'small']
# 4.0
# wings [100]
# 48.0
# drinks None
# wings [100]
# 48.0
# drinks ['medium', 'tub', 'tub']
# 10.5
# wings None
# drinks None
# wings [100, 10, 10]
# 58.0
# drinks None
# wings [40]
# 17.5
# drinks ['small', 'medium']
# 5.0
# wings [20, 100]
# 57.0
# drinks None
# wings [40]
# 17.5
# drinks ['tub']
# 3.75
# wings [100]
# 48.0
# drinks ['medium', 'tub', 'tub']
# 10.5
# wings None
# drinks ['small', 'small']
# 4.0
# wings [100, 10]
# 53.0
# drinks ['large', 'small']
# 5.5
# wings [10]
# 5.0
# drinks None
# wings [40]
# 17.5
# drinks ['tub']
# 3.75
# wings [40, 40, 40]
# 52.5
# drinks None
# wings [40, 40]
# 35.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['small', 'small', 'large']
# 7.5
# wings [40, 10]
# 22.5
# drinks None
# wings [100, 40]
# 65.5
# drinks None
# wings [10, 40, 40]
# 40.0
# drinks ['tub', 'small', 'small']
# 7.75
# wings [20, 40]
# 26.5
# drinks ['large', 'tub']
# 7.25
# wings [100]
# 48.0
# drinks ['tub', 'large', 'small']
# 9.25
# wings [10]
# 5.0
# drinks None
# wings None
# drinks ['large']
# 3.5
# wings [10]
# 5.0
# drinks ['large', 'small']
# 5.5
# wings [100, 20]
# 57.0
# drinks ['large', 'medium']
# 6.5
# wings [40, 10]
# 22.5
# drinks ['medium']
# 3.0
# wings [40, 10]
# 22.5
# drinks ['medium', 'medium', 'large']
# 9.5
# wings [40]
# 17.5
# drinks None
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['medium', 'large', 'large']
# 10.0
# wings None
# drinks ['tub', 'small']
# 5.75
# wings None
# drinks None
# wings [20, 100]
# 57.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['large', 'small']
# 5.5
# wings [10, 100, 100]
# 101.0
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings [10]
# 5.0
# drinks None
# wings None
# drinks ['small', 'tub']
# 5.75
# wings [100, 10, 100]
# 101.0
# drinks ['tub', 'large', 'tub']
# 11.0
# wings None
# drinks ['tub', 'small']
# 5.75
# wings [100]
# 48.0
# drinks ['large', 'small']
# 5.5
# wings [100, 10, 10]
# 58.0
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings [100, 10, 10]
# 58.0
# drinks ['large', 'tub']
# 7.25
# wings [100, 100]
# 96.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['small', 'tub']
# 5.75
# wings [100, 20]
# 57.0
# drinks ['medium', 'medium', 'small']
# 8.0
# wings [20]
# 9.0
# drinks None
# wings [10]
# 5.0
# drinks None
# wings [100, 10, 100]
# 101.0
# drinks ['medium']
# 3.0
# wings [10, 100]
# 53.0
# drinks ['large', 'small', 'medium']
# 8.5
# wings [20, 20]
# 18.0
# drinks None
# wings None
# drinks ['small', 'tub']
# 5.75
# wings [40, 40, 100]
# 83.0
# drinks ['large', 'small']
# 5.5
# wings None
# drinks None
# wings None
# drinks ['large', 'large']
# 7.0
# wings [100, 40, 10]
# 70.5
# drinks ['small']
# 2.0
# wings [40, 20, 100]
# 74.5
# drinks None
# wings None
# drinks ['small', 'medium', 'small']
# 7.0
# wings None
# drinks ['tub', 'tub', 'medium']
# 10.5
# wings [100, 100]
# 96.0
# drinks ['tub', 'medium', 'medium']
# 9.75
# wings [20, 40]
# 26.5
# drinks ['medium', 'medium', 'large']
# 9.5
# wings [40, 20, 100]
# 74.5
# drinks None
# wings [100]
# 48.0
# drinks ['large', 'tub', 'small']
# 9.25
# wings [100, 40]
# 65.5
# drinks ['tub']
# 3.75
# wings [100, 100]
# 96.0
# drinks ['medium']
# 3.0
# wings [100]
# 48.0
# drinks ['small']
# 2.0
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['large', 'tub']
# 7.25
# wings [10, 20, 20]
# 23.0
# drinks ['tub', 'large']
# 7.25
# wings [100]
# 48.0
# drinks ['large', 'small']
# 5.5
# wings [100, 40, 10]
# 70.5
# drinks ['large', 'medium', 'medium']
# 9.5
# wings [10, 10, 100]
# 58.0
# drinks ['small']
# 2.0
# wings [40]
# 17.5
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks None
# wings None
# drinks ['tub', 'large']
# 7.25
# wings None
# drinks ['large', 'medium', 'small']
# 8.5
# wings [40, 40, 40]
# 52.5
# drinks ['medium', 'medium']
# 6.0
# wings [40, 40, 20]
# 44.0
# drinks None
# wings None
# drinks ['tub', 'large']
# 7.25
# wings [100, 10, 20]
# 62.0
# drinks ['large', 'medium', 'medium']
# 9.5
# wings [100]
# 48.0
# drinks ['large', 'tub', 'small']
# 9.25
# wings [100, 100]
# 96.0
# drinks ['large', 'tub']
# 7.25
# wings [40]
# 17.5
# drinks ['tub', 'medium']
# 6.75
# wings None
# drinks ['medium', 'medium']
# 6.0
# wings [20, 10, 40]
# 31.5
# drinks ['small']
# 2.0
# wings [20]
# 9.0
# drinks ['medium']
# 3.0
# wings [40]
# 17.5
# drinks ['tub', 'small', 'small']
# 7.75
# wings [40, 10]
# 22.5
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [40, 10, 10]
# 27.5
# drinks None
# wings None
# drinks ['tub', 'medium']
# 6.75
# wings [20, 40]
# 26.5
# drinks ['tub']
# 3.75
# wings [100, 40]
# 65.5
# drinks ['tub', 'large']
# 7.25
# wings [20, 100]
# 57.0
# drinks None
# wings None
# drinks ['small']
# 2.0
# wings [20, 20]
# 18.0
# drinks ['small']
# 2.0
# wings [20, 100, 10]
# 62.0
# drinks ['tub', 'tub', 'medium']
# 10.5
# wings None
# drinks ['tub', 'small', 'small']
# 7.75
# wings [20]
# 9.0
# drinks ['medium', 'small', 'small']
# 7.0
# wings [20]
# 9.0
# drinks ['medium', 'large', 'tub']
# 10.25
# wings [20, 20, 100]
# 66.0
# drinks ['medium', 'small', 'tub']
# 8.75
# wings None
# drinks ['small', 'medium', 'tub']
# 8.75
# wings [10, 20, 40]
# 31.5
# drinks None
# wings [20, 20, 100]
# 66.0
# drinks ['tub', 'small']
# 5.75
# wings [10]
# 5.0
# drinks ['small', 'small']
# 4.0
# wings [40, 100]
# 65.5
# drinks ['large', 'small']
# 5.5
# wings None
# drinks ['medium', 'medium', 'tub']
# 9.75
# wings [20, 40, 10]
# 31.5
# drinks ['medium']
# 3.0
# wings None
# drinks ['large', 'medium']
# 6.5
# wings [20]
# 9.0
# drinks ['small']
# 2.0
# wings [100]
# 48.0
# drinks ['tub', 'small']
# 5.75
# wings [10]
# 5.0
# drinks ['medium', 'tub']
# 6.75
# wings [20]
# 9.0
# drinks ['tub', 'small', 'medium']
# 8.75
# wings [20, 10]
# 14.0
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks ['small', 'medium']
# 5.0
# wings None
# drinks ['small']
# 2.0
# wings None
# drinks ['small', 'tub', 'large']
# 9.25
# wings [10]
# 5.0
# drinks ['small', 'small']
# 4.0
# wings None
# drinks None
# wings None
# drinks None
# wings None
# drinks ['small', 'large']
# 5.5
# wings [10, 40]
# 22.5
# drinks ['large', 'medium', 'tub']
# 10.25
# wings [40]
# 17.5
# drinks ['small', 'medium']
# 5.0
# wings [100]
# 48.0
# drinks ['medium']
# 3.0
# wings [100, 20]
# 57.0
# drinks ['small']
# 2.0
# wings [10, 10, 10]
# 15.0
# drinks None
# wings None
# drinks None
# wings [20, 20, 20]
# 27.0
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks ['tub']
# 3.75
# wings [100, 100]
# 96.0
# drinks None
# wings [40, 20, 100]
# 74.5
# drinks ['large', 'small']
# 5.5
# wings [100]
# 48.0
# drinks None
# wings [10]
# 5.0
# drinks ['large', 'medium']
# 6.5
# wings None
# drinks ['large', 'large', 'large']
# 10.5
# wings None
# drinks None
# wings None
# drinks None
# wings None
# drinks ['tub']
# 3.75
# wings [20, 100]
# 57.0
# drinks None
# wings [100]
# 48.0
# drinks ['large']
# 3.5
# wings None
# drinks ['medium', 'medium']
# 6.0
# wings [40, 20]
# 26.5
# drinks ['tub', 'medium', 'small']
# 8.75
# wings [100]
# 48.0
# drinks ['tub']
# 3.75
# wings None
# drinks ['medium']
# 3.0
# wings [40, 20, 100]
# 74.5
# drinks ['tub']
# 3.75
# wings [100, 10, 20]
# 62.0
# drinks None
# wings [100, 40]
# 65.5
# drinks ['small']
# 2.0
# wings [40, 20, 40]
# 44.0
# drinks None
# wings [20]
# 9.0
# drinks ['tub', 'tub']
# 7.5
# wings [100, 20]
# 57.0
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks ['large', 'medium']
# 6.5
# wings [20]
# 9.0
# drinks ['large']
# 3.5
# wings None
# drinks None
# wings None
# drinks ['medium', 'small']
# 5.0
# wings None
# drinks ['tub', 'medium']
# 6.75
# wings None
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks ['tub', 'tub']
# 7.5
# wings [10]
# 5.0
# drinks ['tub', 'tub', 'medium']
# 10.5
# wings [40, 20, 10]
# 31.5
# drinks ['tub']
# 3.75
# wings [20, 10]
# 14.0
# drinks ['small', 'large']
# 5.5
# wings [40]
# 17.5
# drinks ['large', 'large', 'tub']
# 10.75
# wings [10, 100, 10]
# 58.0
# drinks None
# wings None
# drinks ['small', 'tub', 'small']
# 7.75
# wings [10, 40]
# 22.5
# drinks ['medium', 'large']
# 6.5
# wings [20, 20, 20]
# 27.0
# drinks ['large', 'small']
# 5.5
# wings [100, 20]
# 57.0
# drinks None
# wings [20]
# 9.0
# drinks ['medium']
# 3.0
# wings [20, 100, 20]
# 66.0
# drinks ['large', 'large', 'large']
# 10.5
# wings [10, 10, 40]
# 27.5
# drinks ['small', 'small', 'large']
# 7.5
# wings None
# drinks ['small']
# 2.0
# wings [20, 40]
# 26.5
# drinks ['tub']
# 3.75
# wings [10, 10]
# 10.0
# drinks ['medium']
# 3.0
# wings [10, 100]
# 53.0
# drinks ['tub', 'medium']
# 6.75
# wings [10]
# 5.0
# drinks ['tub', 'large', 'medium']
# 10.25
# wings [40, 20, 40]
# 44.0
# drinks ['tub', 'large']
# 7.25
# wings [20]
# 9.0
# drinks ['medium', 'tub']
# 6.75
# wings [100]
# 48.0
# drinks None
# wings [100, 40, 40]
# 83.0
# drinks ['medium', 'medium']
# 6.0
# wings None
# drinks ['medium', 'medium', 'tub']
# 9.75
# wings None
# drinks None
# wings None
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [40]
# 17.5
# drinks ['large', 'tub', 'large']
# 10.75
# wings [10]
# 5.0
# drinks ['medium', 'medium', 'large']
# 9.5
# wings None
# drinks ['tub']
# 3.75
# wings [10]
# 5.0
# drinks ['medium', 'large']
# 6.5
# wings [40, 40, 10]
# 40.0
# drinks None
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['large', 'small']
# 5.5
# wings [40]
# 17.5
# drinks ['tub']
# 3.75
# wings None
# drinks ['large', 'large']
# 7.0
# wings None
# drinks ['small', 'medium', 'large']
# 8.5
# wings [100]
# 48.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['small', 'tub']
# 5.75
# wings None
# drinks ['large', 'medium']
# 6.5
# wings None
# drinks ['small', 'medium']
# 5.0
# wings None
# drinks None
# wings None
# drinks ['medium']
# 3.0
# wings None
# drinks ['medium', 'small']
# 5.0
# wings None
# drinks ['small', 'small', 'small']
# 6.0
# wings [40, 20]
# 26.5
# drinks None
# wings [100, 40]
# 65.5
# drinks None
# wings [40]
# 17.5
# drinks ['medium', 'medium']
# 6.0
# wings None
# drinks ['large', 'small', 'tub']
# 9.25
# wings None
# drinks ['small']
# 2.0
# wings [100, 10, 10]
# 58.0
# drinks ['small', 'tub', 'tub']
# 9.5
# wings None
# drinks ['small']
# 2.0
# wings [40, 20]
# 26.5
# drinks ['medium', 'large', 'small']
# 8.5
# wings [20, 40]
# 26.5
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings [20, 20, 20]
# 27.0
# drinks ['large', 'small', 'large']
# 9.0
# wings [100, 10]
# 53.0
# drinks ['large', 'medium', 'small']
# 8.5
# wings None
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks ['medium', 'tub', 'large']
# 10.25
# wings None
# drinks None
# wings [100, 40, 10]
# 70.5
# drinks ['large', 'medium', 'tub']
# 10.25
# wings [40, 20, 40]
# 44.0
# drinks ['tub', 'tub']
# 7.5
# wings [20]
# 9.0
# drinks ['small', 'large', 'tub']
# 9.25
# wings None
# drinks None
# wings [10, 100, 100]
# 101.0
# drinks ['small']
# 2.0
# wings [40, 100]
# 65.5
# drinks None
# wings None
# drinks None
# wings [20, 20, 20]
# 27.0
# drinks ['small']
# 2.0
# wings None
# drinks ['tub', 'medium']
# 6.75
# wings None
# drinks None
# wings None
# drinks ['large', 'tub', 'large']
# 10.75
# wings None
# drinks ['tub', 'small']
# 5.75
# wings [10, 10, 20]
# 19.0
# drinks ['tub', 'small', 'medium']
# 8.75
# wings None
# drinks ['medium', 'tub']
# 6.75
# wings [10]
# 5.0
# drinks ['small', 'tub']
# 5.75
# wings [20]
# 9.0
# drinks None
# wings [10]
# 5.0
# drinks ['tub', 'large']
# 7.25
# wings [10, 20, 100]
# 62.0
# drinks ['medium', 'medium', 'medium']
# 9.0
# wings [20, 40]
# 26.5
# drinks ['large', 'medium']
# 6.5
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['tub', 'small']
# 5.75
# wings [20]
# 9.0
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks ['small', 'small', 'large']
# 7.5
# wings [40, 100, 20]
# 74.5
# drinks None
# wings None
# drinks ['medium']
# 3.0
# wings [10, 10]
# 10.0
# drinks ['medium', 'large', 'medium']
# 9.5
# wings [20, 20, 100]
# 66.0
# drinks None
# wings [10]
# 5.0
# drinks ['tub', 'small']
# 5.75
# wings None
# drinks None
# wings None
# drinks ['tub', 'tub']
# 7.5
# wings None
# drinks ['tub', 'medium', 'small']
# 8.75
# wings None
# drinks ['large', 'small', 'tub']
# 9.25
# wings [20]
# 9.0
# drinks ['medium']
# 3.0
# wings [40, 10]
# 22.5
# drinks ['medium']
# 3.0
# wings None
# drinks ['large', 'medium', 'tub']
# 10.25
# wings None
# drinks ['small']
# 2.0
# wings [100, 10, 40]
# 70.5
# drinks ['medium']
# 3.0
# wings [40]
# 17.5
# drinks ['medium', 'small', 'small']
# 7.0
# wings [10, 20]
# 14.0
# drinks ['small', 'tub', 'tub']
# 9.5
# wings [100, 20, 40]
# 74.5
# drinks ['tub']
# 3.75
# wings [100]
# 48.0
# drinks ['large', 'small', 'medium']
# 8.5
# wings [100, 40]
# 65.5
# drinks ['tub']
# 3.75
# wings [40]
# 17.5
# drinks ['large']
# 3.5
# wings [40, 10, 20]
# 31.5
# drinks None
# wings [40, 10]
# 22.5
# drinks ['medium', 'medium']
# 6.0
# wings None
# drinks ['small', 'large']
# 5.5
# wings [10]
# 5.0
# drinks ['medium', 'small', 'medium']
# 8.0
# wings [20, 10]
# 14.0
# drinks ['small']
# 2.0
# wings [100, 20]
# 57.0
# drinks ['tub', 'tub', 'large']
# 11.0
# wings None
# drinks ['medium']
# 3.0
# wings None
# drinks None
# wings None
# drinks None
# wings None
# drinks ['large', 'medium', 'large']
# 10.0
# wings [100, 40, 20]
# 74.5
# drinks ['tub', 'small', 'tub']
# 9.5
# wings [40]
# 17.5
# drinks None
# wings None
# drinks ['small', 'tub', 'tub']
# 9.5
# wings None
# drinks ['small', 'large']
# 5.5
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings None
# drinks ['medium', 'tub', 'large']
# 10.25
# wings [10]
# 5.0
# drinks ['medium', 'medium', 'large']
# 9.5
# wings None
# drinks None
# wings [100, 40, 40]
# 83.0
# drinks None
# wings None
# drinks ['small', 'medium']
# 5.0
# wings [20]
# 9.0
# drinks None
# wings [100, 100, 40]
# 113.5
# drinks ['medium', 'tub', 'small']
# 8.75
# wings [10]
# 5.0
# drinks ['small', 'medium']
# 5.0
# wings [40, 100]
# 65.5
# drinks ['tub']
# 3.75
# wings [20, 10]
# 14.0
# drinks None
# wings [100]
# 48.0
# drinks ['medium', 'small']
# 5.0
# wings [20, 40]
# 26.5
# drinks ['tub', 'small', 'small']
# 7.75
# wings [10]
# 5.0
# drinks ['large', 'tub']
# 7.25
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings [20]
# 9.0
# drinks None
# wings None
# drinks ['large', 'medium']
# 6.5
# wings [20, 40, 100]
# 74.5
# drinks ['small', 'medium', 'large']
# 8.5
# wings None
# drinks ['large', 'tub', 'small']
# 9.25
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings None
# drinks None
# wings [10, 20, 10]
# 19.0
# drinks ['medium']
# 3.0
# wings [40]
# 17.5
# drinks ['tub', 'small', 'tub']
# 9.5
# wings [20]
# 9.0
# drinks None
# wings None
# drinks ['medium', 'small', 'medium']
# 8.0
# wings [100, 100, 100]
# 144.0
# drinks ['small']
# 2.0
# wings [100, 10, 10]
# 58.0
# drinks None
# wings [100, 20]
# 57.0
# drinks ['tub', 'large', 'small']
# 9.25
# wings [20, 20]
# 18.0
# drinks ['tub', 'small', 'medium']
# 8.75
# wings None
# drinks ['tub', 'small']
# 5.75
# wings [10, 40, 40]
# 40.0
# drinks ['small']
# 2.0
# wings [100]
# 48.0
# drinks ['medium', 'tub', 'medium']
# 9.75
# wings None
# drinks ['tub']
# 3.75
# wings [100, 100, 10]
# 101.0
# drinks ['medium', 'medium']
# 6.0
# wings [40, 100]
# 65.5
# drinks ['small', 'tub']
# 5.75
# wings [20, 100, 40]
# 74.5
# drinks None
# wings [20, 20, 40]
# 35.5
# drinks ['tub', 'small', 'medium']
# 8.75
# wings [10, 40]
# 22.5
# drinks None
# wings [20, 20, 20]
# 27.0
# drinks ['large']
# 3.5
# wings [20, 20, 20]
# 27.0
# drinks ['tub', 'large']
# 7.25
# wings [10, 20, 100]
# 62.0
# drinks None
# wings None
# drinks ['small', 'medium', 'tub']
# 8.75
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings [20, 20, 100]
# 66.0
# drinks ['large']
# 3.5
# wings [20, 10]
# 14.0
# drinks ['large', 'tub']
# 7.25
# wings [40, 10]
# 22.5
# drinks ['large', 'large', 'tub']
# 10.75
# wings [100, 10, 100]
# 101.0
# drinks ['tub', 'large']
# 7.25
# wings [40]
# 17.5
# drinks None
# wings [10, 20]
# 14.0
# drinks None
# wings [20]
# 9.0
# drinks ['small', 'tub']
# 5.75
# wings [20, 100]
# 57.0
# drinks ['medium', 'tub']
# 6.75
# wings [40, 40, 10]
# 40.0
# drinks ['medium', 'small', 'large']
# 8.5
# wings [10]
# 5.0
# drinks None
# wings [40, 40]
# 35.0
# drinks ['tub']
# 3.75
# wings [20]
# 9.0
# drinks None
# wings [100, 40, 100]
# 113.5
# drinks ['medium']
# 3.0
# wings [10]
# 5.0
# drinks ['small', 'tub', 'medium']
# 8.75
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['medium', 'large', 'tub']
# 10.25
# wings [10, 100]
# 53.0
# drinks ['small', 'small']
# 4.0
# wings [40, 20]
# 26.5
# drinks ['large']
# 3.5
# wings [100, 20]
# 57.0
# drinks ['small', 'tub']
# 5.75
# wings [40]
# 17.5
# drinks ['small', 'tub', 'small']
# 7.75
# wings [10, 100]
# 53.0
# drinks ['medium']
# 3.0
# wings [10, 100, 40]
# 70.5
# drinks ['large', 'small']
# 5.5
# wings [20]
# 9.0
# drinks ['large', 'medium']
# 6.5
# wings None
# drinks ['small', 'medium', 'medium']
# 8.0
# wings [10, 10]
# 10.0
# drinks None
# wings [10, 10]
# 10.0
# drinks None
# wings None
# drinks ['tub']
# 3.75
# wings [10]
# 5.0
# drinks ['medium']
# 3.0
# wings [10]
# 5.0
# drinks None
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings [10, 100]
# 53.0
# drinks None
# wings None
# drinks ['medium']
# 3.0
# wings [40]
# 17.5
# drinks ['medium', 'medium', 'tub']
# 9.75
# wings [40, 10]
# 22.5
# drinks None
# wings None
# drinks None
# wings None
# drinks ['tub']
# 3.75
# wings [100]
# 48.0
# drinks ['large', 'large', 'tub']
# 10.75
# wings None
# drinks None
# wings None
# drinks ['tub', 'medium']
# 6.75
# wings [20]
# 9.0
# drinks ['large', 'medium', 'medium']
# 9.5
# wings [10, 10]
# 10.0
# drinks ['tub']
# 3.75
# wings [40, 100]
# 65.5
# drinks ['medium', 'medium', 'tub']
# 9.75
# wings [100]
# 48.0
# drinks None
# wings None
# drinks ['small']
# 2.0
# wings [100, 100]
# 96.0
# drinks ['large']
# 3.5
# wings [10]
# 5.0
# drinks ['tub']
# 3.75
# wings [10, 100]
# 53.0
# drinks ['medium', 'medium']
# 6.0
# wings [10, 10, 20]
# 19.0
# drinks ['small', 'small']
# 4.0
# wings [10, 40]
# 22.5
# drinks ['small', 'large', 'tub']
# 9.25
# wings [40, 20, 20]
# 35.5
# drinks ['medium', 'tub']
# 6.75
# wings [40]
# 17.5
# drinks None
# wings [20, 10]
# 14.0
# drinks ['large', 'medium']
# 6.5
# wings None
# drinks None
# wings [40]
# 17.5
# drinks ['tub', 'tub']
# 7.5
# wings None
# drinks ['tub', 'small', 'small']
# 7.75
# wings [40, 20, 10]
# 31.5
# drinks None
# wings [10, 10, 10]
# 15.0
# drinks ['medium', 'tub']
# 6.75
# wings [40, 10, 100]
# 70.5
# drinks ['small', 'small']
# 4.0
# wings None
# drinks ['tub']
# 3.75
# wings [20, 20, 20]
# 27.0
# drinks ['large']
# 3.5
# wings [40, 10, 40]
# 40.0
# drinks None
# wings [10]
# 5.0
# drinks None
# wings [40, 10]
# 22.5
# drinks None
# wings None
# drinks ['tub']
# 3.75
# wings [20]
# 9.0
# drinks ['medium', 'large']
# 6.5
# wings [10, 40]
# 22.5
# drinks None
# wings [100, 100, 100]
# 144.0
# drinks None
# wings [10]
# 5.0
# drinks ['medium']
# 3.0
# wings [100]
# 48.0
# drinks None
# wings None
# drinks ['medium', 'large', 'small']
# 8.5
# wings None
# drinks ['medium', 'medium']
# 6.0
# wings [100, 40]
# 65.5
# drinks None
# wings [20, 20]
# 18.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['tub', 'medium', 'large']
# 10.25
# wings [10, 10, 20]
# 19.0
# drinks ['tub']
# 3.75
# wings None
# drinks ['small']
# 2.0
# wings None
# drinks ['large', 'medium', 'tub']
# 10.25
# wings None
# drinks None
# wings [20]
# 9.0
# drinks ['large']
# 3.5
# wings [20]
# 9.0
# drinks ['tub']
# 3.75
# wings [10]
# 5.0
# drinks ['large']
# 3.5
# wings [40]
# 17.5
# drinks ['medium', 'medium']
# 6.0
# wings [40, 100]
# 65.5
# drinks ['medium', 'medium']
# 6.0
# wings [20, 100]
# 57.0
# drinks ['large', 'large']
# 7.0
# wings None
# drinks ['tub', 'small', 'large']
# 9.25
# wings None
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks None
# wings [10]
# 5.0
# drinks ['tub', 'medium', 'tub']
# 10.5
# wings [100]
# 48.0
# drinks ['tub', 'medium']
# 6.75
# wings [100, 100, 40]
# 113.5
# drinks ['medium']
# 3.0
# wings [20, 100, 10]
# 62.0
# drinks ['large', 'tub', 'small']
# 9.25
# wings [10]
# 5.0
# drinks ['medium', 'medium']
# 6.0
# wings [40, 20]
# 26.5
# drinks ['medium']
# 3.0
# wings [100]
# 48.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['tub', 'large']
# 7.25
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['large']
# 3.5
# wings [10, 20, 40]
# 31.5
# drinks ['large', 'large']
# 7.0
# wings None
# drinks ['tub']
# 3.75
# wings [10]
# 5.0
# drinks ['tub', 'large']
# 7.25
# wings [40, 40, 100]
# 83.0
# drinks None
# wings [10]
# 5.0
# drinks ['medium', 'medium', 'small']
# 8.0
# wings [40, 10, 20]
# 31.5
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks ['large', 'large']
# 7.0
# wings None
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [20, 100, 20]
# 66.0
# drinks None
# wings [40, 100]
# 65.5
# drinks ['large', 'large']
# 7.0
# wings [40]
# 17.5
# drinks ['small']
# 2.0
# wings [10, 40, 20]
# 31.5
# drinks ['tub']
# 3.75
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings [20, 40, 40]
# 44.0
# drinks None
# wings [20, 10]
# 14.0
# drinks None
# wings [20, 100, 10]
# 62.0
# drinks ['small']
# 2.0
# wings [20, 20, 100]
# 66.0
# drinks ['small', 'small', 'large']
# 7.5
# wings [100, 20, 20]
# 66.0
# drinks ['small']
# 2.0
# wings [40]
# 17.5
# drinks None
# wings None
# drinks ['medium']
# 3.0
# wings [10]
# 5.0
# drinks None
# wings [40, 10, 10]
# 27.5
# drinks ['small', 'small']
# 4.0
# wings None
# drinks ['small']
# 2.0
# wings [20]
# 9.0
# drinks None
# wings [20, 100, 40]
# 74.5
# drinks None
# wings [100, 40]
# 65.5
# drinks ['small', 'small', 'large']
# 7.5
# wings [20, 100]
# 57.0
# drinks ['medium', 'tub']
# 6.75
# wings [40, 10, 10]
# 27.5
# drinks ['large']
# 3.5
# wings [100, 40]
# 65.5
# drinks ['medium', 'small', 'medium']
# 8.0
# wings [20]
# 9.0
# drinks None
# wings [20]
# 9.0
# drinks None
# wings [100, 20]
# 57.0
# drinks None
# wings [10]
# 5.0
# drinks ['large']
# 3.5
# wings None
# drinks ['tub', 'medium', 'small']
# 8.75
# wings [100, 10, 40]
# 70.5
# drinks ['small', 'tub', 'small']
# 7.75
# wings [100]
# 48.0
# drinks None
# wings [100]
# 48.0
# drinks ['large']
# 3.5
# wings [10, 100, 20]
# 62.0
# drinks ['medium', 'large', 'tub']
# 10.25
# wings [100]
# 48.0
# drinks ['small']
# 2.0
# wings [100, 100, 40]
# 113.5
# drinks ['large', 'small']
# 5.5
# wings [20, 100]
# 57.0
# drinks ['tub', 'small', 'small']
# 7.75
# wings [40]
# 17.5
# drinks ['large', 'large']
# 7.0
# wings [20]
# 9.0
# drinks None
# wings None
# drinks ['medium', 'small', 'tub']
# 8.75
# wings None
# drinks ['medium', 'medium', 'medium']
# 9.0
# wings [40, 100, 40]
# 83.0
# drinks ['small', 'medium']
# 5.0
# wings [20]
# 9.0
# drinks ['medium']
# 3.0
# wings [100, 20]
# 57.0
# drinks ['medium', 'small']
# 5.0
# wings [100]
# 48.0
# drinks ['tub', 'tub']
# 7.5
# wings [40]
# 17.5
# drinks ['tub', 'tub']
# 7.5
# wings [40, 40, 100]
# 83.0
# drinks None
# wings [10]
# 5.0
# drinks None
# wings [20, 100, 20]
# 66.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['large', 'tub', 'small']
# 9.25
# wings [40, 10, 20]
# 31.5
# drinks None
# wings [100]
# 48.0
# drinks ['tub', 'tub', 'large']
# 11.0
# wings None
# drinks ['small', 'large']
# 5.5
# wings [40, 10, 10]
# 27.5
# drinks ['tub', 'medium', 'medium']
# 9.75
# wings [10, 10]
# 10.0
# drinks ['tub']
# 3.75
# wings [100]
# 48.0
# drinks None
# wings [40, 20, 20]
# 35.5
# drinks None
# wings [10, 40]
# 22.5
# drinks None
# wings [40, 10]
# 22.5
# drinks ['tub']
# 3.75
# wings [20, 20, 100]
# 66.0
# drinks ['tub']
# 3.75
# wings [100, 10, 100]
# 101.0
# drinks ['tub', 'tub', 'medium']
# 10.5
# wings [20, 20, 40]
# 35.5
# drinks None
# wings [20]
# 9.0
# drinks ['tub', 'tub', 'small']
# 9.5
# wings [100, 20, 100]
# 105.0
# drinks ['medium']
# 3.0
# wings [20, 40, 20]
# 35.5
# drinks ['large', 'large', 'large']
# 10.5
# wings None
# drinks ['medium', 'small', 'large']
# 8.5
# wings None
# drinks ['small']
# 2.0
# wings None
# drinks None
# wings [20, 40, 100]
# 74.5
# drinks ['large', 'large', 'large']
# 10.5
# wings [20, 20, 40]
# 35.5
# drinks ['large', 'tub']
# 7.25
# wings None
# drinks None
# wings [10, 100, 40]
# 70.5
# drinks ['small', 'medium']
# 5.0
# wings [10, 10]
# 10.0
# drinks None
# wings None
# drinks None
# wings None
# drinks ['tub', 'small']
# 5.75
# wings [20, 10, 40]
# 31.5
# drinks ['tub', 'tub']
# 7.5
# wings None
# drinks None
# wings [10]
# 5.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['large', 'tub']
# 7.25
# wings [100]
# 48.0
# drinks None
# wings [10, 20]
# 14.0
# drinks None
# wings [10]
# 5.0
# drinks None
# wings [10, 40]
# 22.5
# drinks ['small']
# 2.0
# wings None
# drinks None
# wings [40, 20, 10]
# 31.5
# drinks None
# wings [20]
# 9.0
# drinks ['medium', 'small']
# 5.0
# wings [100]
# 48.0
# drinks ['large']
# 3.5
# wings [100]
# 48.0
# drinks None
# wings None
# drinks ['tub', 'tub']
# 7.5
# wings None
# drinks ['small', 'small', 'large']
# 7.5
# wings [40, 100]
# 65.5
# drinks ['large', 'medium']
# 6.5
# wings [100, 100]
# 96.0
# drinks ['medium', 'tub', 'small']
# 8.75
# wings [100, 10]
# 53.0
# drinks None
# wings [20]
# 9.0
# drinks ['large', 'large']
# 7.0
# wings [100]
# 48.0
# drinks None
# wings [100, 100, 40]
# 113.5
# drinks ['medium', 'large']
# 6.5
# wings [10, 20, 100]
# 62.0
# drinks ['large']
# 3.5
# wings None
# drinks ['small', 'tub', 'small']
# 7.75
# wings [20, 10, 100]
# 62.0
# drinks ['tub', 'medium']
# 6.75
# wings [10]
# 5.0
# drinks ['small', 'large']
# 5.5
# wings [100, 20]
# 57.0
# drinks ['small', 'tub']
# 5.75
# wings [10, 10]
# 10.0
# drinks None
# wings [40]
# 17.5
# drinks ['small']
# 2.0
# wings [10, 100, 10]
# 58.0
# drinks ['small']
# 2.0
# wings None
# drinks ['medium', 'tub']
# 6.75
# wings [100, 10]
# 53.0
# drinks ['medium', 'large']
# 6.5
# wings [20, 10]
# 14.0
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks ['small', 'medium', 'medium']
# 8.0
# wings None
# drinks ['large']
# 3.5
# wings [20, 10, 100]
# 62.0
# drinks ['tub']
# 3.75
# wings [100, 10]
# 53.0
# drinks ['large']
# 3.5
# wings None
# drinks ['tub', 'large', 'medium']
# 10.25
# wings [100, 40]
# 65.5
# drinks ['tub', 'small', 'medium']
# 8.75
# wings [40, 10, 40]
# 40.0
# drinks ['tub', 'tub']
# 7.5
# wings [40, 20]
# 26.5
# drinks ['large']
# 3.5
# wings [10, 40, 20]
# 31.5
# drinks ['medium', 'tub', 'large']
# 10.25
# wings None
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks ['tub']
# 3.75
# wings [20]
# 9.0
# drinks None
# wings [10, 20]
# 14.0
# drinks ['tub', 'large']
# 7.25
# wings None
# drinks ['medium', 'large', 'large']
# 10.0
# wings [100, 20]
# 57.0
# drinks ['large']
# 3.5
# wings [40, 10]
# 22.5
# drinks ['medium', 'medium']
# 6.0
# wings [20]
# 9.0
# drinks None
# wings [10, 100]
# 53.0
# drinks ['medium', 'tub', 'medium']
# 9.75
# wings [40, 10, 40]
# 40.0
# drinks None
# wings None
# drinks ['tub']
# 3.75
# wings [40]
# 17.5
# drinks ['tub', 'medium']
# 6.75
# wings [100]
# 48.0
# drinks None
# wings [40, 20]
# 26.5
# drinks ['medium']
# 3.0
# wings [10]
# 5.0
# drinks ['large', 'tub', 'large']
# 10.75
# wings [100]
# 48.0
# drinks None
# wings [40, 40, 20]
# 44.0
# drinks ['tub', 'tub', 'small']
# 9.5
# wings [100, 20]
# 57.0
# drinks ['small']
# 2.0
# wings [20, 100, 10]
# 62.0
# drinks ['tub']
# 3.75
# wings None
# drinks ['large', 'large', 'tub']
# 10.75
# wings [10, 20, 40]
# 31.5
# drinks ['medium', 'small', 'medium']
# 8.0
# wings [10, 10, 20]
# 19.0
# drinks ['medium']
# 3.0
# wings [40, 100, 40]
# 83.0
# drinks None
# wings [100, 20]
# 57.0
# drinks ['medium']
# 3.0
# wings [20, 10]
# 14.0
# drinks ['large', 'tub']
# 7.25
# wings [100, 40, 40]
# 83.0
# drinks ['tub', 'large']
# 7.25
# wings [100]
# 48.0
# drinks ['small', 'large']
# 5.5
# wings [10, 10]
# 10.0
# drinks ['small', 'small']
# 4.0
# wings [10, 100]
# 53.0
# drinks ['medium', 'medium']
# 6.0
# wings [40]
# 17.5
# drinks ['tub', 'small']
# 5.75
# wings [40]
# 17.5
# drinks ['small', 'tub', 'medium']
# 8.75
# wings [20, 20]
# 18.0
# drinks ['small', 'large']
# 5.5
# wings None
# drinks ['tub', 'tub']
# 7.5
# wings None
# drinks None
# wings [100, 100, 100]
# 144.0
# drinks ['tub', 'large', 'medium']
# 10.25
# wings [20, 20, 10]
# 23.0
# drinks None
# wings [20]
# 9.0
# drinks ['large', 'tub', 'tub']
# 11.0
# wings [20, 40, 100]
# 74.5
# drinks None
# wings [100, 10]
# 53.0
# drinks ['tub', 'small', 'large']
# 9.25
# wings [20, 10, 10]
# 19.0
# drinks ['tub']
# 3.75
# wings [40, 100, 10]
# 70.5
# drinks ['tub', 'tub']
# 7.5
# wings [20, 40, 20]
# 35.5
# drinks ['tub', 'tub', 'large']
# 11.0
# wings None
# drinks None
# wings None
# drinks ['large', 'small']
# 5.5
# wings [20, 40, 20]
# 35.5
# drinks ['tub', 'medium', 'tub']
# 10.5
# wings None
# drinks ['tub', 'small', 'small']
# 7.75
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings [20, 20]
# 18.0
# drinks ['medium']
# 3.0
# wings None
# drinks None
# wings [10]
# 5.0
# drinks ['medium', 'large', 'tub']
# 10.25
# wings [40, 40, 100]
# 83.0
# drinks ['medium', 'large', 'medium']
# 9.5
# wings None
# drinks ['large', 'small', 'large']
# 9.0
# wings [40, 20]
# 26.5
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings None
# drinks ['small', 'large']
# 5.5
# wings [100, 20]
# 57.0
# drinks ['large']
# 3.5
# wings None
# drinks ['tub', 'tub', 'tub']
# 11.25
# wings [10]
# 5.0
# drinks ['small', 'large']
# 5.5
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings None
# drinks ['large']
# 3.5
# wings [10, 10, 10]
# 15.0
# drinks ['large', 'small', 'large']
# 9.0
# wings [40]
# 17.5
# drinks ['small', 'small', 'small']
# 6.0
# wings [100, 10]
# 53.0
# drinks ['tub', 'medium', 'small']
# 8.75
# wings [100]
# 48.0
# drinks ['small', 'medium', 'small']
# 7.0
# wings [100, 20]
# 57.0
# drinks ['medium', 'small']
# 5.0
# wings None
# drinks ['medium', 'small']
# 5.0
# wings [40, 10]
# 22.5
# drinks ['tub']
# 3.75
# wings None
# drinks ['small', 'large', 'tub']
# 9.25
# wings [20, 10, 100]
# 62.0
# drinks ['tub']
# 3.75
# wings None
# drinks ['tub', 'tub', 'small']
# 9.5
# wings [100, 100]
# 96.0
# drinks ['medium', 'tub', 'large']
# 10.25
# wings [100]
# 48.0
# drinks None
# wings [20, 40, 20]
# 35.5
# drinks ['medium', 'medium']
# 6.0
# wings None
# drinks None
# wings [40]
# 17.5
# drinks ['large']
# 3.5
# wings [40, 20]
# 26.5
# drinks None
# wings [40, 20, 40]
# 44.0
# drinks None
# wings [20, 40, 100]
# 74.5
# drinks ['tub', 'medium']
# 6.75
# wings [40]
# 17.5
# drinks None
# wings [100]
# 48.0
# drinks ['tub']
# 3.75
# wings [20, 100, 20]
# 66.0
# drinks ['medium', 'large']
# 6.5
# wings [20]
# 9.0
# drinks None
# wings [100]
# 48.0
# drinks ['medium', 'tub', 'small']
# 8.75
# wings [100]
# 48.0
# drinks None
# wings [100, 20, 100]
# 105.0
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [10, 40]
# 22.5
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [40, 40]
# 35.0
# drinks ['medium']
# 3.0
# wings [100, 20]
# 57.0
# drinks ['small', 'medium']
# 5.0
# wings [40, 100, 40]
# 83.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['large']
# 3.5
# wings [20, 100]
# 57.0
# drinks ['large', 'small', 'medium']
# 8.5
# wings None
# drinks None
# wings [100, 40]
# 65.5
# drinks ['tub', 'large']
# 7.25
# wings [10, 100]
# 53.0
# drinks ['large', 'medium']
# 6.5
# wings None
# drinks ['medium', 'tub', 'tub']
# 10.5
# wings [40]
# 17.5
# drinks ['small', 'tub', 'large']
# 9.25
# wings [20]
# 9.0
# drinks ['tub']
# 3.75
# wings [100, 40, 20]
# 74.5
# drinks ['medium', 'tub']
# 6.75
# wings [40]
# 17.5
# drinks ['large']
# 3.5
# wings [20, 40]
# 26.5
# drinks ['tub', 'large', 'tub']
# 11.0
# wings None
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [20]
# 9.0
# drinks ['large']
# 3.5
# wings [100]
# 48.0
# drinks ['tub']
# 3.75
# wings [40, 10]
# 22.5
# drinks ['tub', 'medium', 'large']
# 10.25
# wings None
# drinks None
# wings [100, 100]
# 96.0
# drinks ['medium', 'small']
# 5.0
# wings [20, 20, 10]
# 23.0
# drinks None
# wings None
# drinks ['tub', 'large', 'large']
# 10.75
# wings None
# drinks None
# wings [10, 100, 20]
# 62.0
# drinks ['medium']
# 3.0
# wings [20, 40]
# 26.5
# drinks ['small', 'small', 'medium']
# 7.0
# wings None
# drinks None
# wings [40, 10]
# 22.5
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks ['large', 'tub', 'small']
# 9.25
# wings [20, 20]
# 18.0
# drinks ['small', 'tub']
# 5.75
# wings [100, 10, 40]
# 70.5
# drinks ['tub', 'large', 'tub']
# 11.0
# wings None
# drinks ['large', 'small']
# 5.5
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['small']
# 2.0
# wings [20, 100, 100]
# 105.0
# drinks ['small', 'large']
# 5.5
# wings [20, 100, 40]
# 74.5
# drinks ['small', 'tub', 'tub']
# 9.5
# wings [10, 40]
# 22.5
# drinks None
# wings [20, 10, 20]
# 23.0
# drinks None
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings [40]
# 17.5
# drinks ['medium', 'large', 'tub']
# 10.25
# wings [40]
# 17.5
# drinks ['small']
# 2.0
# wings None
# drinks ['small', 'tub', 'tub']
# 9.5
# wings [40, 40, 20]
# 44.0
# drinks ['tub', 'medium', 'small']
# 8.75
# wings [10]
# 5.0
# drinks ['tub']
# 3.75
# wings [10, 100]
# 53.0
# drinks ['medium']
# 3.0
# wings [100]
# 48.0
# drinks ['small']
# 2.0
# wings [10, 40]
# 22.5
# drinks ['small', 'medium', 'medium']
# 8.0
# wings [10, 40, 40]
# 40.0
# drinks ['tub']
# 3.75
# wings [10]
# 5.0
# drinks ['medium', 'medium', 'tub']
# 9.75
# wings [20, 10, 40]
# 31.5
# drinks ['large', 'small']
# 5.5
# wings None
# drinks ['large']
# 3.5
# wings None
# drinks ['medium']
# 3.0
# wings None
# drinks ['tub', 'tub', 'tub']
# 11.25
# wings [40]
# 17.5
# drinks None
# wings None
# drinks ['medium', 'medium', 'large']
# 9.5
# wings [40, 40, 40]
# 52.5
# drinks ['large']
# 3.5
# wings [40, 20, 10]
# 31.5
# drinks ['medium', 'large', 'large']
# 10.0
# wings None
# drinks ['medium', 'small', 'large']
# 8.5
# wings None
# drinks ['small', 'large']
# 5.5
# wings [10, 100]
# 53.0
# drinks ['medium']
# 3.0
# wings None
# drinks ['large', 'small', 'large']
# 9.0
# wings [100, 100]
# 96.0
# drinks ['small', 'tub', 'tub']
# 9.5
# wings [40, 100, 100]
# 113.5
# drinks ['small', 'large', 'medium']
# 8.5
# wings [40, 10, 10]
# 27.5
# drinks ['medium']
# 3.0
# wings [10]
# 5.0
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [100]
# 48.0
# drinks ['medium', 'medium', 'medium']
# 9.0
# wings None
# drinks None
# wings [10]
# 5.0
# drinks None
# wings [10, 100]
# 53.0
# drinks None
# wings None
# drinks None
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks None
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings None
# drinks ['medium']
# 3.0
# wings [100, 10]
# 53.0
# drinks ['medium', 'small']
# 5.0
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings [40, 40, 100]
# 83.0
# drinks ['medium', 'medium', 'small']
# 8.0
# wings [100, 10]
# 53.0
# drinks ['small', 'tub']
# 5.75
# wings [40]
# 17.5
# drinks None
# wings [10]
# 5.0
# drinks ['large', 'small']
# 5.5
# wings None
# drinks None
# wings [40, 100]
# 65.5
# drinks ['small', 'small', 'small']
# 6.0
# wings [10]
# 5.0
# drinks None
# wings [20, 100, 10]
# 62.0
# drinks ['tub']
# 3.75
# wings [100, 20]
# 57.0
# drinks None
# wings [20]
# 9.0
# drinks ['small', 'medium', 'medium']
# 8.0
# wings None
# drinks ['tub']
# 3.75
# wings [20, 40, 10]
# 31.5
# drinks ['large', 'medium']
# 6.5
# wings [10, 10]
# 10.0
# drinks ['tub', 'medium', 'medium']
# 9.75
# wings [100]
# 48.0
# drinks ['large']
# 3.5
# wings [100, 10]
# 53.0
# drinks ['large', 'medium', 'medium']
# 9.5
# wings [100]
# 48.0
# drinks ['medium']
# 3.0
# wings [20, 100, 100]
# 105.0
# drinks ['medium']
# 3.0
# wings [100]
# 48.0
# drinks None
# wings None
# drinks ['large', 'tub']
# 7.25
# wings [20, 100, 10]
# 62.0
# drinks None
# wings [100, 10]
# 53.0
# drinks ['medium', 'large', 'small']
# 8.5
# wings None
# drinks None
# wings [40, 40]
# 35.0
# drinks ['medium', 'small', 'small']
# 7.0
# wings [100, 100]
# 96.0
# drinks ['large']
# 3.5
# wings None
# drinks ['tub', 'small']
# 5.75
# wings None
# drinks None
# wings None
# drinks ['tub', 'tub']
# 7.5
# wings None
# drinks ['tub', 'medium']
# 6.75
# wings [100, 10, 100]
# 101.0
# drinks None
# wings [20]
# 9.0
# drinks None
# wings None
# drinks ['large', 'small', 'tub']
# 9.25
# wings [20, 10]
# 14.0
# drinks None
# wings None
# drinks ['large']
# 3.5
# wings [40, 20]
# 26.5
# drinks ['tub', 'medium']
# 6.75
# wings None
# drinks ['tub']
# 3.75
# wings [20, 20]
# 18.0
# drinks None
# wings [10]
# 5.0
# drinks ['large']
# 3.5
# wings None
# drinks ['medium']
# 3.0
# wings [40, 100]
# 65.5
# drinks ['small', 'tub']
# 5.75
# wings None
# drinks ['medium', 'large', 'small']
# 8.5
# wings [40, 40]
# 35.0
# drinks ['small', 'large']
# 5.5
# wings [20, 40]
# 26.5
# drinks None
# wings None
# drinks ['small', 'medium']
# 5.0
# wings None
# drinks ['large', 'tub']
# 7.25
# wings [40]
# 17.5
# drinks ['tub', 'medium']
# 6.75
# wings [100]
# 48.0
# drinks None
# wings [40]
# 17.5
# drinks None
# wings [100]
# 48.0
# drinks ['small', 'tub']
# 5.75
# wings None
# drinks None
# wings None
# drinks ['tub', 'large', 'medium']
# 10.25
# wings [40]
# 17.5
# drinks ['tub', 'medium', 'small']
# 8.75
# wings [100, 20, 10]
# 62.0
# drinks ['large', 'large', 'medium']
# 10.0
# wings [100, 100]
# 96.0
# drinks ['tub', 'medium', 'large']
# 10.25
# wings [40, 100]
# 65.5
# drinks ['large', 'tub']
# 7.25
# wings None
# drinks ['small', 'large', 'medium']
# 8.5
# wings [20, 100]
# 57.0
# drinks ['tub', 'tub']
# 7.5
# wings None
# drinks ['medium', 'large']
# 6.5
# wings None
# drinks ['medium', 'large', 'tub']
# 10.25
# wings None
# drinks ['small', 'small', 'medium']
# 7.0
# wings [10, 40, 100]
# 70.5
# drinks ['small', 'large', 'tub']
# 9.25
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings None
# drinks None
# wings [20]
# 9.0
# drinks ['small', 'large', 'large']
# 9.0
# wings [100]
# 48.0
# drinks ['large']
# 3.5
# wings None
# drinks ['tub', 'small', 'medium']
# 8.75
# wings None
# drinks ['medium']
# 3.0
# wings None
# drinks ['tub']
# 3.75
# wings [40]
# 17.5
# drinks ['large', 'medium']
# 6.5
# wings [10]
# 5.0
# drinks ['tub', 'tub', 'medium']
# 10.5
# wings [40, 100]
# 65.5
# drinks None
# wings [40, 10, 20]
# 31.5
# drinks ['large']
# 3.5
# wings None
# drinks ['medium', 'small', 'large']
# 8.5
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings [40]
# 17.5
# drinks None
# wings None
# drinks None
# wings None
# drinks ['small', 'small']
# 4.0
# wings [10]
# 5.0
# drinks ['small', 'large']
# 5.5
# wings [20, 20, 20]
# 27.0
# drinks ['large']
# 3.5
# wings [10, 20]
# 14.0
# drinks None
# wings [20, 100]
# 57.0
# drinks ['small']
# 2.0
# wings None
# drinks ['medium']
# 3.0
# wings [20, 100]
# 57.0
# drinks ['tub', 'large', 'small']
# 9.25
# wings None
# drinks ['medium']
# 3.0
# wings [20, 10, 10]
# 19.0
# drinks ['tub']
# 3.75
# wings [20]
# 9.0
# drinks ['medium', 'tub']
# 6.75
# wings [20, 100, 20]
# 66.0
# drinks ['tub', 'medium', 'small']
# 8.75
# wings None
# drinks None
# wings None
# drinks ['tub', 'large', 'large']
# 10.75
# wings [40]
# 17.5
# drinks ['tub', 'small']
# 5.75
# wings [10, 100, 10]
# 58.0
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks ['tub']
# 3.75
# wings [10, 20, 10]
# 19.0
# drinks ['tub', 'medium']
# 6.75
# wings None
# drinks ['medium', 'tub']
# 6.75
# wings None
# drinks ['large']
# 3.5
# wings [20]
# 9.0
# drinks ['large', 'large', 'large']
# 10.5
# wings [40, 20]
# 26.5
# drinks ['small', 'large', 'large']
# 9.0
# wings None
# drinks ['medium']
# 3.0
# wings [40, 20]
# 26.5
# drinks ['small', 'large']
# 5.5
# wings [10]
# 5.0
# drinks ['small', 'large', 'tub']
# 9.25
# wings [10]
# 5.0
# drinks ['large']
# 3.5
# wings [10]
# 5.0
# drinks ['tub', 'small', 'small']
# 7.75
# wings [40]
# 17.5
# drinks None
# wings [40, 100]
# 65.5
# drinks None
# wings [10, 20]
# 14.0
# drinks None
# wings [40]
# 17.5
# drinks ['small', 'large', 'tub']
# 9.25
# wings None
# drinks ['medium', 'medium']
# 6.0
# wings [100, 100, 20]
# 105.0
# drinks None
# wings None
# drinks ['medium']
# 3.0
# wings [40, 40]
# 35.0
# drinks ['tub', 'tub']
# 7.5
# wings [10]
# 5.0
# drinks ['tub', 'tub']
# 7.5
# wings [100, 20]
# 57.0
# drinks ['large', 'medium']
# 6.5
# wings [100, 20]
# 57.0
# drinks ['medium', 'small', 'tub']
# 8.75
# wings [100]
# 48.0
# drinks ['small']
# 2.0
# wings None
# drinks None
# wings [100, 20]
# 57.0
# drinks ['large']
# 3.5
# wings [100, 100, 10]
# 101.0
# drinks None
# wings [100]
# 48.0
# drinks ['small', 'medium', 'large']
# 8.5
# wings None
# drinks ['small']
# 2.0
# wings None
# drinks None
# wings [10]
# 5.0
# drinks ['tub']
# 3.75
# wings [10]
# 5.0
# drinks ['medium']
# 3.0
# wings [100, 20, 20]
# 66.0
# drinks ['small', 'large', 'large']
# 9.0
# wings [10, 40, 20]
# 31.5
# drinks ['tub', 'large']
# 7.25
# wings [100, 100]
# 96.0
# drinks None
# wings [20]
# 9.0
# drinks ['large']
# 3.5
# wings [40, 100, 40]
# 83.0
# drinks ['tub']
# 3.75
# wings [10, 40]
# 22.5
# drinks ['medium', 'large']
# 6.5
# wings [100, 100]
# 96.0
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings [20, 100]
# 57.0
# drinks ['tub', 'large']
# 7.25
# wings [20, 40, 10]
# 31.5
# drinks ['tub', 'medium', 'medium']
# 9.75
# wings None
# drinks ['medium']
# 3.0
# wings [10, 40, 10]
# 27.5
# drinks ['large', 'tub']
# 7.25
# wings [100, 10]
# 53.0
# drinks None
# wings None
# drinks None
# wings [20]
# 9.0
# drinks ['small', 'large', 'small']
# 7.5
# wings None
# drinks ['tub']
# 3.75
# wings None
# drinks ['large']
# 3.5
# wings [20]
# 9.0
# drinks ['medium']
# 3.0
# wings [20, 20]
# 18.0
# drinks ['medium', 'large']
# 6.5
# wings [100, 20]
# 57.0
# drinks None
# wings [10, 100, 10]
# 58.0
# drinks ['large', 'large', 'small']
# 9.0
# wings None
# drinks ['medium']
# 3.0
# wings None
# drinks None
# wings [40, 40]
# 35.0
# drinks ['small']
# 2.0
# wings None
# drinks ['small', 'small']
# 4.0
# wings [10, 20, 10]
# 19.0
# drinks ['small', 'small']
# 4.0
# wings [40]
# 17.5
# drinks None
# wings [100]
# 48.0
# drinks ['tub', 'tub']
# 7.5
# wings [100, 100, 40]
# 113.5
# drinks ['tub', 'medium']
# 6.75
# wings [100]
# 48.0
# drinks None
# wings [20, 40]
# 26.5
# drinks ['tub']
# 3.75
# wings None
# drinks None
# wings [10, 20, 40]
# 31.5
# drinks None
# wings [100, 10]
# 53.0
# drinks ['small']
# 2.0
# wings None
# drinks ['large', 'medium']
# 6.5
# wings [20]
# 9.0
# drinks ['tub']
# 3.75
# wings [100]
# 48.0
# drinks None
# wings None
# drinks ['large']
# 3.5
# wings [20]
# 9.0
# drinks ['tub', 'tub', 'small']
# 9.5
# wings [40, 100]
# 65.5
# drinks ['small']
# 2.0
# wings [10]
# 5.0
# drinks ['tub']
# 3.75
# wings None
# drinks ['medium', 'large', 'small']
# 8.5
# wings [100, 20, 10]
# 62.0
# drinks ['small']
# 2.0
# wings [100, 20, 20]
# 66.0
# drinks ['medium']
# 3.0
# wings [100, 10]
# 53.0
# drinks None
# wings [10]
# 5.0
# drinks ['small', 'tub']
# 5.75
# wings None
# drinks None
# wings None
# drinks None
# wings [100, 100]
# 96.0
# drinks ['large', 'tub']
# 7.25
# wings None
# drinks ['small', 'large', 'tub']
# 9.25
# wings [20]
# 9.0
# drinks ['tub', 'small', 'large']
# 9.25
# wings [20, 100]
# 57.0
# drinks None
# wings [40, 100]
# 65.5
# drinks ['small', 'medium']
# 5.0
# wings [20, 20, 20]
# 27.0
# drinks None
# wings [40]
# 17.5
# drinks ['medium']
# 3.0
# wings [40, 10]
# 22.5
# drinks ['medium', 'medium', 'large']
# 9.5
# wings [10, 20]
# 14.0
# drinks ['medium', 'small']
# 5.0
# wings [40]
# 17.5
# drinks ['medium', 'small']
# 5.0
# wings [20]
# 9.0
# drinks ['tub']
# 3.75
# wings [20, 40, 10]
# 31.5
# drinks ['large']
# 3.5
# wings None
# drinks ['small', 'tub', 'small']
# 7.75
# wings [20]
# 9.0
# drinks ['medium', 'small']
# 5.0
# wings [100, 100]
# 96.0
# drinks ['medium']
# 3.0
# wings [40, 10]
# 22.5
# drinks ['large', 'medium', 'medium']
# 9.5
# wings [100]
# 48.0
# drinks None
# wings [40, 10]
# 22.5
# drinks None
# wings [20, 20, 100]
# 66.0
# drinks ['small', 'large']
# 5.5
# wings None
# drinks ['tub', 'small']
# 5.75
# wings [10, 10, 10]
# 15.0
# drinks ['large']
# 3.5
# wings [100, 40, 100]
# 113.5
# drinks ['large', 'medium']
# 6.5
# wings [100]
# 48.0
# drinks ['small']
# 2.0
# wings [100, 10]
# 53.0
# drinks None
# wings [20, 100]
# 57.0
# drinks ['tub', 'tub']
# 7.5
# wings [40, 100, 40]
# 83.0
# drinks None
# wings [40, 40, 20]
# 44.0
# drinks ['tub']
# 3.75
# wings [40, 20]
# 26.5
# drinks None
# wings [100]
# 48.0
# drinks ['small', 'tub', 'tub']
# 9.5
# wings [20, 20, 20]
# 27.0
# drinks ['medium']
# 3.0
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings [40, 40, 100]
# 83.0
# drinks ['small', 'large']
# 5.5
# wings [40, 100, 10]
# 70.5
# drinks ['large']
# 3.5
# wings [40]
# 17.5
# drinks None
# wings None
# drinks None
# wings [100, 40]
# 65.5
# drinks ['large', 'medium']
# 6.5
# wings [20, 40]
# 26.5
# drinks ['large', 'medium']
# 6.5
# wings [20, 100, 100]
# 105.0
# drinks ['medium']
# 3.0
# wings [40, 20]
# 26.5
# drinks ['large', 'large', 'tub']
# 10.75
# wings None
# drinks ['medium', 'medium', 'large']
# 9.5
# wings None
# drinks ['medium', 'tub']
# 6.75
# wings None
# drinks ['small']
# 2.0
# wings None
# drinks ['large', 'tub', 'small']
# 9.25
# wings [100]
# 48.0
# drinks ['medium', 'medium', 'tub']
# 9.75
# wings [20, 40]
# 26.5
# drinks ['tub', 'medium']
# 6.75
# wings [10, 20]
# 14.0
# drinks ['small']
# 2.0
# wings [20]
# 9.0
# drinks ['medium', 'medium', 'tub']
# 9.75
# wings [20, 10]
# 14.0
# drinks ['tub', 'tub']
# 7.5
# wings [100, 100, 10]
# 101.0
# drinks ['tub', 'medium', 'small']
# 8.75
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings [20, 10, 40]
# 31.5
# drinks ['large', 'tub']
# 7.25
# wings [20]
# 9.0
# drinks ['tub']
# 3.75
# wings None
# drinks ['medium', 'large', 'small']
# 8.5
# wings [40, 20, 20]
# 35.5
# drinks ['large']
# 3.5
# wings None
# drinks ['medium']
# 3.0
# wings [20, 10]
# 14.0
# drinks None
# wings [100, 20]
# 57.0
# drinks ['large', 'small', 'tub']
# 9.25
# wings [100]
# 48.0
# drinks ['small']
# 2.0
# wings [100]
# 48.0
# drinks ['medium']
# 3.0
# wings [100]
# 48.0
# drinks ['medium', 'small', 'large']
# 8.5
# wings [40]
# 17.5
# drinks ['small', 'small']
# 4.0
# wings [40]
# 17.5
# drinks ['medium', 'small']
# 5.0
# wings [10, 100]
# 53.0
# drinks None
# wings None
# drinks None
# wings [20]
# 9.0
# drinks ['tub', 'small']
# 5.75
# wings None
# drinks ['small']
# 2.0
# wings None
# drinks ['tub']
# 3.75
# wings [100, 10]
# 53.0
# drinks ['tub', 'tub']
# 7.5
# wings [20, 10, 40]
# 31.5
# drinks ['large', 'small']
# 5.5
# wings [20]
# 9.0
# drinks None
# wings [20, 20]
# 18.0
# drinks ['large', 'small', 'small']
# 7.5
# wings None
# drinks ['small', 'tub', 'small']
# 7.75
# wings None
# drinks None
# wings [100, 10]
# 53.0
# drinks ['large', 'tub']
# 7.25
# wings [20, 10]
# 14.0
# drinks ['large', 'medium', 'small']
# 8.5
# wings None
# drinks None
# wings [100, 20, 10]
# 62.0
# drinks ['large', 'small']
# 5.5
# wings [40]
# 17.5
# drinks None
# wings [10, 10]
# 10.0
# drinks None
# wings None
# drinks ['large', 'small']
# 5.5
# wings [10, 100]
# 53.0
# drinks ['large', 'medium', 'medium']
# 9.5
# wings None
# drinks ['large']
# 3.5
# wings [40]
# 17.5
# drinks ['tub']
# 3.75
# wings [10, 20, 10]
# 19.0
# drinks None
# wings [100, 20]
# 57.0
# drinks ['tub', 'medium', 'large']
# 10.25
# wings None
# drinks ['medium', 'small']
# 5.0
# wings [10]
# 5.0
# drinks ['small']
# 2.0
# wings [40, 20]
# 26.5
# drinks ['medium']
# 3.0
# wings None
# drinks None
# wings [100, 100]
# 96.0
# drinks None
# wings [20]
# 9.0
# drinks None
# wings None
# drinks ['small', 'medium']
# 5.0
# wings [10, 10]
# 10.0
# drinks ['small', 'tub']
# 5.75
# wings [20, 100]
# 57.0
# drinks ['medium', 'medium', 'small']
# 8.0
# wings None
# drinks None
# wings [100, 100, 20]
# 105.0
# drinks ['medium', 'tub', 'medium']
# 9.75
# wings None
# drinks ['tub']
# 3.75
# wings [20, 100, 100]
# 105.0
# drinks ['medium', 'tub', 'tub']
# 10.5
# wings [100]
# 48.0
# drinks ['large', 'small']
# 5.5
# wings [40, 10]
# 22.5
# drinks None
# wings [100, 100, 100]
# 144.0
# drinks ['medium', 'small']
# 5.0
# wings [10, 20]
# 14.0
# drinks None
# wings [20]
# 9.0
# drinks ['medium']
# 3.0
# wings [40, 40, 10]
# 40.0
# drinks ['large', 'small']
# 5.5
# wings [20, 10, 20]
# 23.0
# drinks ['medium']
# 3.0
# wings None
# drinks None
# wings [40, 10]
# 22.5
# drinks ['tub']
# 3.75
# wings [10, 40]
# 22.5
# drinks ['tub', 'large', 'tub']
# 11.0
# wings [100]
# 48.0
# drinks ['small', 'tub', 'small']
# 7.75
# wings [10, 10, 20]
# 19.0
# drinks None
# wings None
# drinks ['small', 'small', 'tub']
# 7.75
# wings [10, 10]
# 10.0
# drinks ['medium', 'large', 'small']
# 8.5
# wings [10]
# 5.0
# drinks ['small', 'medium', 'small']
# 7.0
# wings None
# drinks ['large', 'large', 'small']
# 9.0
# wings [40, 100]
# 65.5
#
# ============================== ALL TESTS PASSED! ===============================
# Your submission code: bw376a5897c31ca763c949f9e3e3b48926ae5e8e0dfb0210f3f59d4485
# ================================================================================

# %%
import numpy as np
a = np.linspace(0,20,100)
print(a)
# Out:
# [ 0.          0.2020202   0.4040404   0.60606061  0.80808081  1.01010101
#   1.21212121  1.41414141  1.61616162  1.81818182  2.02020202  2.22222222
#   2.42424242  2.62626263  2.82828283  3.03030303  3.23232323  3.43434343
#   3.63636364  3.83838384  4.04040404  4.24242424  4.44444444  4.64646465
#   4.84848485  5.05050505  5.25252525  5.45454545  5.65656566  5.85858586
#   6.06060606  6.26262626  6.46464646  6.66666667  6.86868687  7.07070707
#   7.27272727  7.47474747  7.67676768  7.87878788  8.08080808  8.28282828
#   8.48484848  8.68686869  8.88888889  9.09090909  9.29292929  9.49494949
#   9.6969697   9.8989899  10.1010101  10.3030303  10.50505051 10.70707071
#  10.90909091 11.11111111 11.31313131 11.51515152 11.71717172 11.91919192
#  12.12121212 12.32323232 12.52525253 12.72727273 12.92929293 13.13131313
#  13.33333333 13.53535354 13.73737374 13.93939394 14.14141414 14.34343434
#  14.54545455 14.74747475 14.94949495 15.15151515 15.35353535 15.55555556
#  15.75757576 15.95959596 16.16161616 16.36363636 16.56565657 16.76767677
#  16.96969697 17.17171717 17.37373737 17.57575758 17.77777778 17.97979798
#  18.18181818 18.38383838 18.58585859 18.78787879 18.98989899 19.19191919
#  19.39393939 19.5959596  19.7979798  20.        ]
